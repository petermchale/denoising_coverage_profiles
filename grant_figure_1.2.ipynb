# %% [markdown]
# ### Denoising a noisy region via a deep learning model that overfits the observed depths

# %%
# %matplotlib inline

from plot import plot_corrected_depths_dev_all

plot_corrected_depths_dev_all([{'path': '../data/trained_models/05_mediumTrain_exactCoverage/', 
                                'annotation': 'medium train set (single depth value)', 
                                'figure_file_name': '1.2A.pdf'}], 
                              show_title=False)

# %%
from plot import plot_depths_dev_all
plot_depths_dev_all([{'path': '../data/trained_models/05_mediumTrain_exactCoverage/', 
                                'annotation': 'medium train set (single depth value)'}], max_depth=200)

# %% [markdown]
# ### The denoising procedure preserves putative true deletions

# %%
from plot import plot_corrected_depths_test_all
plot_corrected_depths_test_all([{'path': '../data/trained_models/08_veryLargeTrain_randomWindow',
                                 'annotation': 'high quality deletion',                                  
                                 'figure_file_name': '1.2B.pdf', 
                                 'test_file_name': 'test.pkl'}],
                               max_y=3,
                               show_title=False)
