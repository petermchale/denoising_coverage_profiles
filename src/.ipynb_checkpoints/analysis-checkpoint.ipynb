# %% [markdown]
# Train a Convolution Neural Network to map DNA sequence onto observed read depth. Then "correct" observed depths by dividing by the predicted depth.

# %%
from main import correct_depths
correct_depths()
# Out:
# epoch: 0 cost: 129.00581 observed_depths: [294.79  77.06  27.35] predicted_depths: [1.0620718 1.0512139 1.0367867]
# epoch: 100 cost: 8.998751 observed_depths: [294.79  77.06  27.35] predicted_depths: [98.35233  32.3143   33.602863]
# epoch: 200 cost: 6.017107 observed_depths: [294.79  77.06  27.35] predicted_depths: [254.47478  42.93022  37.78959]
# epoch: 300 cost: 4.390977 observed_depths: [294.79  77.06  27.35] predicted_depths: [294.32562   51.527447  36.5163  ]
# epoch: 400 cost: 3.4987996 observed_depths: [294.79  77.06  27.35] predicted_depths: [296.2412    59.773125  33.477436]
# epoch: 500 cost: 3.065076 observed_depths: [294.79  77.06  27.35] predicted_depths: [296.1806    67.124344  30.661272]
# epoch: 600 cost: 2.869366 observed_depths: [294.79  77.06  27.35] predicted_depths: [295.73312   72.446014  28.80559 ]
# epoch: 700 cost: 2.782778 observed_depths: [294.79  77.06  27.35] predicted_depths: [295.34332   75.32242   27.770794]
# ...

# %% [markdown]
# Compare the corrected genomic profile with the observed depths (normalized by their mean):

# %%
# %matplotlib inline 
from main import visualize
visualize()
