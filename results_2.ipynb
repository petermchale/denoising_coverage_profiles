# %% [markdown]
# ### Modifying the distribution of read depths in the training data

# %%
trained_models = [
    {'path': '../data/trained_models/09_100samples_day1/09_100samples_uniformDistribution/', 'annotation': 'uniform distribution; 1 day of training'},
    {'path': '../data/trained_models/09_100samples_day1/09_100samples_humpedDistribution/', 'annotation': 'humped distribution; 1 day of training'},
    {'path': '../data/trained_models/09_100samples_day2/09_100samples_uniformDistribution/', 'annotation': 'uniform distribution; 2 days of training'},
    {'path': '../data/trained_models/09_100samples_day2/09_100samples_humpedDistribution/', 'annotation': 'humped distribution; 2 days of training'}
]

start_epoch = 0.001
end_epoch = 1000
min_cost = 1
max_cost = 100000

# %matplotlib inline 

from plot import plot_costs_all
plot_costs_all(trained_models, start_epoch=start_epoch, end_epoch=end_epoch, min_cost=min_cost, max_cost=max_cost, loglog=True)
# Out:
# observed_depth_mean 2975.668
# observed_depth_mean 2807.989
# observed_depth_mean 2975.668
# observed_depth_mean 2807.989

# %%
from plot import plot_corrected_depths_train_all
plot_corrected_depths_train_all(trained_models, chromosome_number=22)

# %%
from plot import plot_depths_train_all
plot_depths_train_all(trained_models, chromosome_number=22, max_depth=8000)

# %%
from plot import plot_corrected_depths_test_all
plot_corrected_depths_test_all(trained_models, chromosome_number=22, max_y=3)

# %%
from plot import plot_depths_test_all
plot_depths_test_all(trained_models, chromosome_number=22, max_depth=8000)
