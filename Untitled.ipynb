# %%
trained_models = [
    {'path': '../data/trained_models/09_100samples_originalDistribution/', 'annotation': '100 samples; original distribution'},
    {'path': '../data/trained_models/09_100samples_uniformDistribution/', 'annotation': '100 samples; uniform distribution'},
    {'path': '../data/trained_models/09_100samples_humpedDistribution/', 'annotation': '100 samples; humped distribution'}
]

start_epoch = 0.001
end_epoch = 1000
min_cost = 1
max_cost = 100000

# %matplotlib inline 

from plot import plot_costs_all
plot_costs_all(trained_models, start_epoch=start_epoch, end_epoch=end_epoch, min_cost=min_cost, max_cost=max_cost, loglog=True)

# %%
plot_corrected_depths_train_all(trained_models_randomWindows)
